# %% [markdown]
# ## Generative AI
# ---
#
# ::::{grid} 1 1 2 3
# :gutter: 3
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Model Families</span>
# ^^^
#
# * [01-Transformer](Gen-AI/01-Model-Families/01-Transformer.ipynb)
# * [02-Encoder-Decoder-Models](Gen-AI/01-Model-Families/02-Encoder-Decoder-Models.ipynb)
# * [03-Decoder-Only-Models](Gen-AI/01-Model-Families/03-Decoder-Only-Models.ipynb)
# * [04-Mixture-of-Experts](Gen-AI/01-Model-Families/04-Mixture-of-Experts.ipynb)
# * [05-Diffusion-Models](Gen-AI/01-Model-Families/05-Diffusion-Models.ipynb)
# * [06-Variational-Autoencoders](Gen-AI/01-Model-Families/06-Variational-Autoencoders.ipynb)
# * [07-GANs](Gen-AI/01-Model-Families/07-GANs.ipynb)
# * [08-Autoregressive-Models](Gen-AI/01-Model-Families/08-Autoregressive-Models.ipynb)
# * [09-State-Space-Models](Gen-AI/01-Model-Families/09-State-Space-Models.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Key Architectural Components</span>
# ^^^
#
# * [01-Self-Attention](Gen-AI/02-Key-Architectural-Components/01-Self-Attention.ipynb)
# * [02-Multi-Head-Attention](Gen-AI/02-Key-Architectural-Components/02-Multi-Head-Attention.ipynb)
# * [03-Positional-Encoding](Gen-AI/02-Key-Architectural-Components/03-Positional-Encoding.ipynb)
# * [04-Feedforward-Networks](Gen-AI/02-Key-Architectural-Components/04-Feedforward-Networks.ipynb)
# * [05-Layer-Normalization](Gen-AI/02-Key-Architectural-Components/05-Layer-Normalization.ipynb)
# * [06-Residual-Connections](Gen-AI/02-Key-Architectural-Components/06-Residual-Connections.ipynb)
# * [07-Cross-Attention](Gen-AI/02-Key-Architectural-Components/07-Cross-Attention.ipynb)
# * [08-Sparse-Attention](Gen-AI/02-Key-Architectural-Components/08-Sparse-Attention.ipynb)
# * [09-Rotary-Embeddings](Gen-AI/02-Key-Architectural-Components/09-Rotary-Embeddings.ipynb)
# * [10-KV-Caching](Gen-AI/02-Key-Architectural-Components/10-KV-Caching.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Model Training Concepts</span>
# ^^^
#
# * [01-Pretraining](Gen-AI/03-Model-Training-Concepts/01-Pretraining.ipynb)
# * [02-Self-supervised-learning](Gen-AI/03-Model-Training-Concepts/02-Self-supervised-learning.ipynb)
# * [03-Instruction-tuning](Gen-AI/03-Model-Training-Concepts/03-Instruction-tuning.ipynb)
# * [04-Supervised-fine-tuning](Gen-AI/03-Model-Training-Concepts/04-Supervised-fine-tuning.ipynb)
# * [05-RLHF](Gen-AI/03-Model-Training-Concepts/05-RLHF.ipynb)
# * [06-Preference-modeling](Gen-AI/03-Model-Training-Concepts/06-Preference-modeling.ipynb)
# * [07-Curriculum-learning](Gen-AI/03-Model-Training-Concepts/07-Curriculum-learning.ipynb)
# * [08-Continual-learning](Gen-AI/03-Model-Training-Concepts/08-Continual-learning.ipynb)
# * [09-Model-alignment](Gen-AI/03-Model-Training-Concepts/09-Model-alignment.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Core LLM Generation Concepts</span>
# ^^^
#
# * [01-Tokenization](Gen-AI/04-Core-LLM-Generation-Concepts/01-Tokenization.ipynb)
# * [02-Context-window](Gen-AI/04-Core-LLM-Generation-Concepts/02-Context-window.ipynb)
# * [03-Inference](Gen-AI/04-Core-LLM-Generation-Concepts/03-Inference.ipynb)
# * [04-Sampling](Gen-AI/04-Core-LLM-Generation-Concepts/04-Sampling.ipynb)
# * [05-Prompting](Gen-AI/04-Core-LLM-Generation-Concepts/05-Prompting.ipynb)
# * [06-Zero-shot-Few-shot-learning](Gen-AI/04-Core-LLM-Generation-Concepts/06-Zero-shot-Few-shot-learning.ipynb)
# * [07-Chain-of-Thought](Gen-AI/04-Core-LLM-Generation-Concepts/07-Chain-of-Thought.ipynb)
# * [08-ReAct-prompting](Gen-AI/04-Core-LLM-Generation-Concepts/08-ReAct-prompting.ipynb)
# * [09-Tool-calling-Function-calling](Gen-AI/04-Core-LLM-Generation-Concepts/09-Tool-calling-Function-calling.ipynb)
# * [10-Structured-generation](Gen-AI/04-Core-LLM-Generation-Concepts/10-Structured-generation.ipynb)
# * [11-Multimodal-generation](Gen-AI/04-Core-LLM-Generation-Concepts/11-Multimodal-generation.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Retrieval & Knowledge Concepts</span>
# ^^^
#
# * [01-Retrieval-Augmented-Generation](Gen-AI/05-Retrieval-Knowledge-Concepts/01-Retrieval-Augmented-Generation.ipynb)
# * [02-Embeddings](Gen-AI/05-Retrieval-Knowledge-Concepts/02-Embeddings.ipynb)
# * [03-11-Beam_Search](Gen-AI/05-Retrieval-Knowledge-Concepts/03-11-Beam_Search.ipynb)
# * [03-Semantic-search](Gen-AI/05-Retrieval-Knowledge-Concepts/03-Semantic-search.ipynb)
# * [04-Hybrid-search](Gen-AI/05-Retrieval-Knowledge-Concepts/04-Hybrid-search.ipynb)
# * [05-Chunking](Gen-AI/05-Retrieval-Knowledge-Concepts/05-Chunking.ipynb)
# * [06-Re-ranking](Gen-AI/05-Retrieval-Knowledge-Concepts/06-Re-ranking.ipynb)
# * [07-Indexing](Gen-AI/05-Retrieval-Knowledge-Concepts/07-Indexing.ipynb)
# * [08-Knowledge-grounding](Gen-AI/05-Retrieval-Knowledge-Concepts/08-Knowledge-grounding.ipynb)
# * [09-Citation-generation](Gen-AI/05-Retrieval-Knowledge-Concepts/09-Citation-generation.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Memory & Context Management</span>
# ^^^
#
# * [01-Short-term-memory](Gen-AI/06-Memory-Context-Management/01-Short-term-memory.ipynb)
# * [02-Long-term-memory](Gen-AI/06-Memory-Context-Management/02-Long-term-memory.ipynb)
# * [03-Conversational-memory](Gen-AI/06-Memory-Context-Management/03-Conversational-memory.ipynb)
# * [04-Session-memory](Gen-AI/06-Memory-Context-Management/04-Session-memory.ipynb)
# * [05-Context-compression](Gen-AI/06-Memory-Context-Management/05-Context-compression.ipynb)
# * [06-Context-pruning](Gen-AI/06-Memory-Context-Management/06-Context-pruning.ipynb)
# * [07-Summarization-memory](Gen-AI/06-Memory-Context-Management/07-Summarization-memory.ipynb)
# * [08-Episodic-memory](Gen-AI/06-Memory-Context-Management/08-Episodic-memory.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Generation Control & Safety</span>
# ^^^
#
# * [01-Hallucination](Gen-AI/07-Generation-Control-Safety/01-Hallucination.ipynb)
# * [02-Guardrails](Gen-AI/07-Generation-Control-Safety/02-Guardrails.ipynb)
# * [03-Content-moderation](Gen-AI/07-Generation-Control-Safety/03-Content-moderation.ipynb)
# * [04-Safety-alignment](Gen-AI/07-Generation-Control-Safety/04-Safety-alignment.ipynb)
# * [05-Bias-mitigation](Gen-AI/07-Generation-Control-Safety/05-Bias-mitigation.ipynb)
# * [06-Toxicity-filtering](Gen-AI/07-Generation-Control-Safety/06-Toxicity-filtering.ipynb)
# * [07-Red-teaming](Gen-AI/07-Generation-Control-Safety/07-Red-teaming.ipynb)
# * [08-Output-constraints](Gen-AI/07-Generation-Control-Safety/08-Output-constraints.ipynb)
# * [09-Prompt-injection](Gen-AI/07-Generation-Control-Safety/09-Prompt-injection.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Model & Data Operations</span>
# ^^^
#
# * [01-Model-serving](Gen-AI/08-Model-Data-Operations/01-Model-serving.ipynb)
# * [02-Model-routing](Gen-AI/08-Model-Data-Operations/02-Model-routing.ipynb)
# * [03-Model-fallback](Gen-AI/08-Model-Data-Operations/03-Model-fallback.ipynb)
# * [04-Distillation](Gen-AI/08-Model-Data-Operations/04-Distillation.ipynb)
# * [05-Quantization](Gen-AI/08-Model-Data-Operations/05-Quantization.ipynb)
# * [06-Caching](Gen-AI/08-Model-Data-Operations/06-Caching.ipynb)
# * [07-Token-optimization](Gen-AI/08-Model-Data-Operations/07-Token-optimization.ipynb)
# * [08-Cost-optimization](Gen-AI/08-Model-Data-Operations/08-Cost-optimization.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Architecture & Infrastructure</span>
# ^^^
#
# * [01-Inference-pipeline](Gen-AI/09-Architecture-Infrastructure/01-Inference-pipeline.ipynb)
# * [02-Orchestration-layer](Gen-AI/09-Architecture-Infrastructure/02-Orchestration-layer.ipynb)
# * [03-LLM-gateway](Gen-AI/09-Architecture-Infrastructure/03-LLM-gateway.ipynb)
# * [04-API-management](Gen-AI/09-Architecture-Infrastructure/04-API-management.ipynb)
# * [05-Microservices-architecture](Gen-AI/09-Architecture-Infrastructure/05-Microservices-architecture.ipynb)
# * [06-Distributed-systems](Gen-AI/09-Architecture-Infrastructure/06-Distributed-systems.ipynb)
# * [07-Event-driven-pipelines](Gen-AI/09-Architecture-Infrastructure/07-Event-driven-pipelines.ipynb)
# * [08-Horizontal-scaling](Gen-AI/09-Architecture-Infrastructure/08-Horizontal-scaling.ipynb)
# * [09-Architecture-Infrastructure](Gen-AI/09-Architecture-Infrastructure/09-Architecture-Infrastructure.ipynb)
# * [09-Load-balancing](Gen-AI/09-Architecture-Infrastructure/09-Load-balancing.ipynb)
# * [10-Rate-limiting](Gen-AI/09-Architecture-Infrastructure/10-Rate-limiting.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title"> Data & Knowledge Infrastructure</span>
# ^^^
#
# * [01-Data-ingestion](Gen-AI/10-Data-Knowledge-Infrastructure/01-Data-ingestion.ipynb)
# * [02-ETL-for-GenAI](Gen-AI/10-Data-Knowledge-Infrastructure/02-ETL-for-GenAI.ipynb)
# * [03-Data-pipelines](Gen-AI/10-Data-Knowledge-Infrastructure/03-Data-pipelines.ipynb)
# * [04-Vector-databases](Gen-AI/10-Data-Knowledge-Infrastructure/04-Vector-databases.ipynb)
# * [05-Metadata-stores](Gen-AI/10-Data-Knowledge-Infrastructure/05-Metadata-stores.ipynb)
# * [06-Feature-stores](Gen-AI/10-Data-Knowledge-Infrastructure/06-Feature-stores.ipynb)
# * [07-Document-stores](Gen-AI/10-Data-Knowledge-Infrastructure/07-Document-stores.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title"> Performance & Reliability</span>
# ^^^
#
# * [01-Latency-optimization](Gen-AI/11-Performance-Reliability/01-Latency-optimization.ipynb)
# * [02-Throughput-optimization](Gen-AI/11-Performance-Reliability/02-Throughput-optimization.ipynb)
# * [03-Streaming](Gen-AI/11-Performance-Reliability/03-Streaming.ipynb)
# * [04-Asynchronous-processing](Gen-AI/11-Performance-Reliability/04-Asynchronous-processing.ipynb)
# * [05-Backpressure-control](Gen-AI/11-Performance-Reliability/05-Backpressure-control.ipynb)
# * [06-Circuit-breakers](Gen-AI/11-Performance-Reliability/06-Circuit-breakers.ipynb)
# * [07-Retries-timeouts](Gen-AI/11-Performance-Reliability/07-Retries-timeouts.ipynb)
# * [08-Graceful-degradation](Gen-AI/11-Performance-Reliability/08-Graceful-degradation.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Security & Compliance</span>
# ^^^
#
# * [01-Data-privacy](Gen-AI/12-Security-Compliance/01-Data-privacy.ipynb)
# * [02-PII-detection-redaction](Gen-AI/12-Security-Compliance/02-PII-detection-redaction.ipynb)
# * [03-Encryption](Gen-AI/12-Security-Compliance/03-Encryption.ipynb)
# * [04-Access-control](Gen-AI/12-Security-Compliance/04-Access-control.ipynb)
# * [05-Authentication-authorization](Gen-AI/12-Security-Compliance/05-Authentication-authorization.ipynb)
# * [06-Audit-logging](Gen-AI/12-Security-Compliance/06-Audit-logging.ipynb)
# * [07-Compliance-frameworks](Gen-AI/12-Security-Compliance/07-Compliance-frameworks.ipynb)
# * [08-Prompt-injection-defense](Gen-AI/12-Security-Compliance/08-Prompt-injection-defense.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Observability & Governance</span>
# ^^^
#
# * [01-Logging](Gen-AI/13-Observability-Governance/01-Logging.ipynb)
# * [02-Monitoring](Gen-AI/13-Observability-Governance/02-Monitoring.ipynb)
# * [03-Tracing](Gen-AI/13-Observability-Governance/03-Tracing.ipynb)
# * [04-Quality-evaluation](Gen-AI/13-Observability-Governance/04-Quality-evaluation.ipynb)
# * [05-Hallucination-tracking](Gen-AI/13-Observability-Governance/05-Hallucination-tracking.ipynb)
# * [06-Feedback-loops](Gen-AI/13-Observability-Governance/06-Feedback-loops.ipynb)
# * [07-AB-testing](Gen-AI/13-Observability-Governance/07-AB-testing.ipynb)
# * [08-Model-governance](Gen-AI/13-Observability-Governance/08-Model-governance.ipynb)
# * [09-Policy-enforcement](Gen-AI/13-Observability-Governance/09-Policy-enforcement.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Advanced GenAI Systems</span>
# ^^^
#
# * [01-Agentic-systems](Gen-AI/14-Advanced-GenAI-Systems/01-Agentic-systems.ipynb)
# * [02-Multi-agent-orchestration](Gen-AI/14-Advanced-GenAI-Systems/02-Multi-agent-orchestration.ipynb)
# * [03-Autonomous-workflows](Gen-AI/14-Advanced-GenAI-Systems/03-Autonomous-workflows.ipynb)
# * [04-Tool-ecosystems](Gen-AI/14-Advanced-GenAI-Systems/04-Tool-ecosystems.ipynb)
# * [05-Workflow-engines](Gen-AI/14-Advanced-GenAI-Systems/05-Workflow-engines.ipynb)
# * [06-Planning-reasoning-systems](Gen-AI/14-Advanced-GenAI-Systems/06-Planning-reasoning-systems.ipynb)
# * [07-Self-reflection-loops](Gen-AI/14-Advanced-GenAI-Systems/07-Self-reflection-loops.ipynb)
# * [08-Multimodal-pipelines](Gen-AI/14-Advanced-GenAI-Systems/08-Multimodal-pipelines.ipynb)
# :::
#
# ::: {grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Product Lifecycle Management</span>
# ^^^
#
# * [01-Prompt-lifecycle-management](Gen-AI/15-Product-Lifecycle-Management/01-Prompt-lifecycle-management.ipynb)
# * [02-Model-lifecycle-management](Gen-AI/15-Product-Lifecycle-Management/02-Model-lifecycle-management.ipynb)
# * [03-Continuous-learning](Gen-AI/15-Product-Lifecycle-Management/03-Continuous-learning.ipynb)
# * [04-Human-in-the-loop-systems](Gen-AI/15-Product-Lifecycle-Management/04-Human-in-the-loop-systems.ipynb)
# * [05-Release-management](Gen-AI/15-Product-Lifecycle-Management/05-Release-management.ipynb)
# * [06-Rollbacks](Gen-AI/15-Product-Lifecycle-Management/06-Rollbacks.ipynb)
# * [07-Experimentation-frameworks](Gen-AI/15-Product-Lifecycle-Management/07-Experimentation-frameworks.ipynb)
# :::
#
# ::::
