# %% [markdown]
# ## Model Families Overview
#
# This section explores the major families of generative AI models, including Transformers, Encoder-Decoder models, GANs, Diffusion Models, and more. Each notebook covers the intuition, architecture, and applications of a specific model family.
#
#
# ```{dropdown} Click here for Sections
# ```{tableofcontents}
# ```
