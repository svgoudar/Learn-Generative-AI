# %% [markdown]
# # Model Training Concepts Overview
#
# This section covers foundational and advanced training paradigms for generative models, including pretraining, fine-tuning, RLHF, curriculum learning, and more. Each notebook explains the workflow, intuition, and best practices for each concept.
#
#
# ```{dropdown} Click here for Sections
# ```{tableofcontents}
# ```
