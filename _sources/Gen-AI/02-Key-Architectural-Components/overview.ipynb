# %% [markdown]
# ## Key Architectural Components Overview
#
# This section details the core building blocks of modern generative models, such as self-attention, multi-head attention, positional encoding, and normalization techniques. Each notebook provides technical explanations and practical insights into these components.
#
#
# ```{dropdown} Click here for Sections
# ```{tableofcontents}
# ```
