# %% [markdown]
# ## Data & Knowledge Infrastructure Overview
#
# This section covers the data infrastructure for GenAI, including ingestion, ETL, pipelines, vector databases, metadata stores, and document stores. Each notebook provides technical and practical guidance for building robust data foundations.
#
#
# ```{dropdown} Click here for Sections
# ```{tableofcontents}
# ```
